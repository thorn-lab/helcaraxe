# %%
import pandas as pd
main_df = pd.read_pickle("/Volumes/My Passport/Helcaraxe/ARM_env/pdb_analysis/PDB_REPORT_pkl/pdb_meta_tab.pkl")

# %%
main_df
# Out:
#        Entry ID  Collection Temperature Experimental Method  \
# PDB ID
# 6HBA       6HBA                   100.0   X-RAY DIFFRACTION
# 6HBB       6HBB                   100.0   X-RAY DIFFRACTION
# 6HBE       6HBE                    93.0   X-RAY DIFFRACTION
# 6HBD       6HBD                   100.0   X-RAY DIFFRACTION
# 6HAX       6HAX                   100.0   X-RAY DIFFRACTION
# ...         ...                     ...                 ...
# 6HA5       6HA5                   100.0   X-RAY DIFFRACTION
# 6HBI       6HBI                   293.0   X-RAY DIFFRACTION
# 6HBM       6HBM                   100.0   X-RAY DIFFRACTION
# 6HC0       6HC0                   100.0   X-RAY DIFFRACTION
# 6HBN       6HBN                   100.0   X-RAY DIFFRACTION
#
#         Matthews Coefficient  Percent Solvent Content  \
# PDB ID
# 6HBA                    1.97                    37.40
# 6HBB                    1.98                    37.77
# 6HBE                    2.40                    48.83
# ...
