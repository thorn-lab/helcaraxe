# %%
import pandas as pd
main_df = pd.read_pickle("/Volumes/My Passport/Helcaraxe/ARM_env/pdb_analysis/main_pdb_meta_test.pkl")
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2627 entries, 2ERV to 5RVL
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Entry ID                        2408 non-null   float64
#  1   Collection Temperature          2500 non-null   object
#  2   Experimental Method             2470 non-null   float64
#  3   Matthews Coefficient            2472 non-null   float64
#  4   Percent Solvent Content         1953 non-null   object
#  5   Crystallization Method          2023 non-null   float64
#  6   pH                              2325 non-null   object
#  7   Crystal Growth Procedure        1982 non-null   float64
#  8   Temp (K)                        2500 non-null   object
#  9   Deposition Date                 2500 non-null   object
#  10  PDB ID                          2500 non-null   float64
#  11  Resolution (Å)                 1858 non-null   float64
# ...

# %%
main_df["Entry ID"].value_counts()
# Out:
# 100.0    1959
# 293.0      49
# 298.0      47
# 110.0      41
# 120.0      27
#          ...
# 99.0        1
# 123.2       1
# 123.0       1
# 83.0        1
# 280.0       1
# Name: Entry ID, Length: 64, dtype: int64

# %%
main_df.head()
# Out:
#       Entry ID Collection Temperature  Experimental Method  \
# 2ERV     100.0      X-RAY DIFFRACTION             3.330000
# 2ES7     100.0      X-RAY DIFFRACTION             2.070000
# 2F47     100.0      X-RAY DIFFRACTION             2.640000
# 2F3U     293.0      X-RAY DIFFRACTION             2.440000
# 2F46     100.0      X-RAY DIFFRACTION             2.006356
#
#       Matthews Coefficient                Percent Solvent Content  \
# 2ERV             63.020000          VAPOR DIFFUSION, HANGING DROP
# 2ES7             40.600000          VAPOR DIFFUSION, HANGING DROP
# 2F47             53.000000          VAPOR DIFFUSION, HANGING DROP
# 2F3U             49.590000                            SMALL TUBES
# 2F46             38.694843  VAPOR DIFFUSION,SITTING DROP,NANODROP
#
#       Crystallization Method  \
# 2ERV                     8.5
# 2ES7                     NaN
# 2F47                     6.5
# 2F3U                     6.7
# 2F46                     8.5
#
# ...
