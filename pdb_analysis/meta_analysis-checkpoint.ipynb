# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import math as ma
main_df = pd.read_pickle("/Users/kristophernolte/Documents/GitHub/helcaraxe/pdb_analysis/PDB_REPORT_pkl/pdb_meta_tab.pkl")
main_df = main_df.reset_index(drop = True)
main_df["Deposition Date"] = pd.to_datetime(main_df["Deposition Date"])

# %%
main_df = main_df.loc[(main_df['I_ice'] != np.nan) & (main_df['F_ice'] != np.nan)]
ice_df = main_df.loc[(main_df['I_ice'] > 0) | (main_df['F_ice'] > 0)]

# %%
"""ice_position = np.load("/Users/kristophernolte/Documents/GitHub/helcaraxe/pdb_analysis/PDB_REPORT_pkl/pdb_ice_tab.npy", allow_pickle=True)
only_pos = pd.DataFrame(np.concatenate(ice_position[:,1]))
only_pos[0].value_counts()"""
# Out:
# 'ice_position = np.load("/Users/kristophernolte/Documents/GitHub/helcaraxe/pdb_analysis/PDB_REPORT_pkl/pdb_ice_tab.npy", allow_pickle=True)\nonly_pos = pd.DataFrame(np.concatenate(ice_position[:,1]))\nonly_pos[0].value_counts()'

# %%
pd.DataFrame(main_df["Deposition Date"].groupby(main_df["Deposition Date"].dt.year).count())
#np.mean(ice_df.loc[(ice_df['Deposition Date'].dt.year < 2020)]["Reflections For Refinement"])
# Out:
#                  Deposition Date
# Deposition Date
# 1980.0                         7
# 1981.0                        23
# 1982.0                        34
# 1983.0                        16
# 1984.0                        26
# 1985.0                        15
# 1986.0                        21
# 1987.0                        43
# 1988.0                        63
# 1989.0                        96
# 1990.0                       154
# 1991.0                       270
# 1992.0                       350
# 1993.0                       569
# 1994.0                       637
# 1995.0                       731
# 1996.0                       919
# 1997.0                      1326
# 1998.0                      1638
# 1999.0                      1594
# 2000.0                      2266
# 2001.0                      2240
# 2002.0                      1202
# 2003.0                      2471
# 2004.0                      4339
# 2005.0                      4980
# 2006.0                      5442
# 2007.0                      6013
# 2008.0                      5926
# 2009.0                      7061
# 2010.0                      7508
# 2011.0                      7817
# 2012.0                      7227
# 2013.0                      7035
# 2014.0                      8056
# 2015.0                      9368
# 2016.0                      9662
# 2017.0                      9367
# 2018.0                      9241
# 2019.0                      8985
# 2020.0                      6818
# 2021.0                       198

# %%
plt.close()
dates_pd = pd.DataFrame(main_df["Deposition Date"].groupby(main_df["Deposition Date"].dt.year).count())
ice_dates_pd = pd.DataFrame(ice_df["Deposition Date"].groupby(ice_df["Deposition Date"].dt.year).count())
dates_pd["prop"] =ice_dates_pd['Deposition Date'] / dates_pd['Deposition Date']
data_amount = dates_pd["Deposition Date"]

def standard_error (amount, prop):
    se = 1.96*ma.sqrt(prop*(1-prop)/amount)
    return se

error_list = []
for data in data_amount:
    se = standard_error(data,0.28)
    error_list.append(se)

y=dates_pd["prop"]
x=dates_pd["prop"].keys()
plt.plot(x,y, color = "darkslateblue")
plt.fill_between(x, y-error_list, y+error_list, alpha=0.5,color = "darkslateblue" )
plt.tick_params(axis='y', which='both', labelleft=False, labelright=True)
plt.tick_params(left=False)
plt.xlim(1980,2021)
plt.ylim(0,1)
plt.xticks([])
plt.savefig("progession_ice.svg", transparent=True)

# %%
main_df["Deposition Date"].groupby(main_df["Deposition Date"].dt.year).count().plot(kind="bar", alpha = 0.5, color="darkseagreen", edgecolor="black", label="deposited diffraction data")
ice_df["Deposition Date"].groupby(ice_df["Deposition Date"].dt.year).count().plot(kind="bar", alpha = 0.5, color="steelblue", edgecolor="black", label="contaminated diffraction data")
dates_pd["prop"].plot()
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(2))
#plt.savefig("ice_contamination_pdb.svg")

# %%
"""main_df[(main_df['Collection Temperature'] == 'Collection Temperature')] = 0
main_df['Collection Temperature'] = main_df['Collection Temperature'].astype("float64")
main_df[(main_df['Collection Temperature'] > 273)]"""
# Out:
#      Entry ID  Collection Temperature        Detector Collection Date  \
# 2Q6G     2Q6G                   298.0     IMAGE PLATE      2005-03-18
# 2PHF     2PHF                   293.0             CCD             NaN
# 6XG3     6XG3                   295.0           PIXEL      2020-05-26
# 1O1I     1O1I                   295.0     IMAGE PLATE      1998-04-15
# 1CJL     1CJL                   298.0  DIFFRACTOMETER      1995-03-14
# 4GFS     4GFS                   295.0             CCD      2012-06-04
# 3V3M     3V3M                   298.0     IMAGE PLATE      2010-03-10
# 1YKZ     1YKZ                   298.0     IMAGE PLATE      2004-05-08
# 4MM3     4MM3                   277.0             CCD      2009-01-01
# 4KDS     4KDS                   293.0             CCD      2013-04-13
# 4GPG     4GPG                   297.0     IMAGE PLATE      2007-06-12
# NaN       NaN                   297.0     IMAGE PLATE      2007-05-01
# 6WQF     6WQF                   293.0           PIXEL      2020-04-06
#
#      Diffraction Source               Diffraction Type  Experimental Method  \
# 2Q6G     ROTATING ANODE            RIGAKU MICROMAX-007    X-RAY DIFFRACTION
# 2PHF        SYNCHROTRON           ESRF BEAMLINE ID14-1    X-RAY DIFFRACTION
# 6XG3        SYNCHROTRON             APS BEAMLINE 19-ID    X-RAY DIFFRACTION
# 1O1I     ROTATING ANODE                        SIEMENS    X-RAY DIFFRACTION
# 1CJL        SYNCHROTRON  PHOTON FACTORY BEAMLINE BL-6A    X-RAY DIFFRACTION
# 4GFS        SYNCHROTRON           APS BEAMLINE 21-ID-D    X-RAY DIFFRACTION
# 3V3M        SYNCHROTRON           APS BEAMLINE 21-ID-G    X-RAY DIFFRACTION
# 1YKZ     ROTATING ANODE                         RIGAKU    X-RAY DIFFRACTION
# 4MM3        SYNCHROTRON           APS BEAMLINE 21-ID-F    X-RAY DIFFRACTION
# 4KDS        SYNCHROTRON         MAX II BEAMLINE I911-2    X-RAY DIFFRACTION
# 4GPG    NUCLEAR REACTOR           JRR-3M BEAMLINE 1G-C    X-RAY DIFFRACTION
# NaN      ROTATING ANODE                MACSCIENCE M06X  NEUTRON DIFFRACTION
# 6WQF     ROTATING ANODE            RIGAKU MICROMAX-007    X-RAY DIFFRACTION
#
#      Matthews Coefficient Percent Solvent Content  \
# 2Q6G                 2.35                    47.6
# 2PHF                 2.63                   53.28
# 6XG3                 3.71                   66.81
# 1O1I                 1.99                    38.1
# 1CJL                 2.35                      48
# 4GFS                 2.05                   40.06
# 3V3M                 3.32                      63
# 1YKZ                 2.11                   41.32
# 4MM3                 2.42                    49.2
# 4KDS                 2.27                   45.77
# 4GPG                  2.1                   41.31
# NaN                   NaN                     NaN
# 6WQF                 2.01                   38.84
#
#              Crystallization Method  ...   R Free   R Work    R All  \
# 2Q6G  VAPOR DIFFUSION, HANGING DROP  ...    0.267    0.199    0.201
# 2PHF  VAPOR DIFFUSION, HANGING DROP  ...    0.216     0.18      NaN
# 6XG3  VAPOR DIFFUSION, HANGING DROP  ...    0.193   0.1513      NaN
# 1O1I                            NaN  ...    0.267      NaN    0.181
# 1CJL                            NaN  ...    0.241    0.182      NaN
# 4GFS  VAPOR DIFFUSION, SITTING DROP  ...  0.24925  0.19878  0.20136
# 3V3M                VAPOR DIFFUSION  ...  0.23572  0.18894      NaN
# 1YKZ  VAPOR DIFFUSION, HANGING DROP  ...    0.225    0.193      NaN
# 4MM3  VAPOR DIFFUSION, HANGING DROP  ...   0.2787   0.1872      NaN
# 4KDS  VAPOR DIFFUSION, SITTING DROP  ...   0.2184   0.1725   0.1748
# 4GPG                VAPOR DIFFUSION  ...   0.2028   0.1466      NaN
# NaN                             NaN  ...   0.2595   0.1952      NaN
# 6WQF  VAPOR DIFFUSION, SITTING DROP  ...   0.2296   0.1796      NaN
#
#      R Observed High Resolution Limit Reflections For Refinement  \
# 2Q6G        NaN                   2.5                      21518
# 2PHF        NaN                   2.1                      34604
# 6XG3     0.1535                  2.48                      18320
# 1O1I      0.174                   2.3                      13580
# 1CJL      0.182                   2.2                      13129
# 4GFS    0.20136                   1.8                      38018
# 3V3M    0.19131                  1.96                      29718
# 1YKZ        NaN                   1.8                      10925
# 4MM3     0.1915                 2.752                      11970
# 4KDS     0.1748                1.6682                      44707
# 4GPG     0.1493                 1.895                      16081
# NaN      0.1984                 1.979                      10998
# 6WQF      0.182                   2.3                      11503
#
#      Structure Determination Method Space Group  \
# 2Q6G          MOLECULAR REPLACEMENT    P 1 21 1
# 2PHF          MOLECULAR REPLACEMENT  P 21 21 21
# 6XG3          MOLECULAR REPLACEMENT    P 32 2 1
# 1O1I          MOLECULAR REPLACEMENT   P 41 21 2
# 1CJL          MOLECULAR REPLACEMENT  P 21 21 21
# 4GFS          MOLECULAR REPLACEMENT    P 1 21 1
# 3V3M          MOLECULAR REPLACEMENT     C 1 2 1
# 1YKZ          MOLECULAR REPLACEMENT   P 43 21 2
# 4MM3          MOLECULAR REPLACEMENT    P 31 2 1
# 4KDS          MOLECULAR REPLACEMENT    P 1 21 1
# 4GPG                            NaN         P 1
# NaN                             NaN         NaN
# 6WQF          MOLECULAR REPLACEMENT     I 1 2 1
#
#                                         Source Organism  \
# 2Q6G                              SARS coronavirus BJ01
# 2PHF                             Pterocarpus angolensis
# 6XG3    Severe acute respiratory syndrome coronavirus 2
# 1O1I                                       Homo sapiens
# 1CJL                                       Homo sapiens
# 4GFS  Salmonella enterica subsp. enterica serovar Ty...
# 3V3M  Severe acute respiratory syndrome-related coro...
# 1YKZ                                      Gallus gallus
# 4MM3                                       Homo sapiens
# 4KDS                                Oncorhynchus mykiss
# 4GPG                              Achromobacter lyticus
# NaN                                                 NaN
# 6WQF    Severe acute respiratory syndrome coronavirus 2
#
#      Molecular Weight (Entity)
# 2Q6G                     33.81
# 2PHF                    27.558
# 6XG3                    35.928
# 1O1I                    15.206
# 1CJL                    35.318
# 4GFS                     27.63
# 3V3M                    33.877
# 1YKZ                    14.331
# 4MM3                     8.561
# 4KDS                    43.091
# 4GPG                    27.759
# NaN                        NaN
# 6WQF                    33.826
#
# [13 rows x 28 columns]

# %%
#convert to type
#main_df["High Resolution Limit"] = main_df["High Resolution Limit"].astype("float64")

#access index for postion
#drop_ind = main_df[(main_df["High Resolution Limit"] > 4)].index
#drop_ind = main_df[(main_df["Collection Temperature"] > 273.0) & (main_df['F_ice'] > 0)].index

#change based on condition
#main_df.loc[main_df['I_ice'] > 0, 'I_ice'] = 1

# %%
"""#convert ice prediction in binary
main_df.loc[main_df['I_ice'] > 0, 'I_ice'] = 1
main_df.loc[main_df['F_ice'] > 0, 'F_ice'] = 1
main_df.loc[main_df['I_ice'] < 0, 'I_ice'] = np.nan
main_df.loc[main_df['F_ice'] < 0, 'F_ice'] = np.nan

main_df["F_ice"].value_counts()
main_df["I_ice"].value_counts()"""
