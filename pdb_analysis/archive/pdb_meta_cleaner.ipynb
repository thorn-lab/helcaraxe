# %%
import pandas as pd

# %%
pkl_path = "/Users/kristophernolte/Documents/GitHub/helcaraxe/pdb_analysis/PDB_REPORT_pkl/train_set_meta"
main_df = pd.read_pickle(pkl_path+".pkl")
main_df.head()
# Out:
#                         Entry ID Collection Temperature         Detector  \
# Entry ID  Collection Temperature               Detector  Collection Date
# 3OJC                         110                    CCD       2010-07-02
# 5R84                         100                  PIXEL       2020-02-27
# 5R83                         100                  PIXEL       2020-02-27
# 5R7Y                         100                  PIXEL       2020-02-26
#
#              Collection Date      Diffraction Source     Diffraction Type  \
# Entry ID  Diffraction Source        Diffraction Type  Experimental Method
# 3OJC             SYNCHROTRON    APS BEAMLINE 21-ID-F    X-RAY DIFFRACTION
# 5R84             SYNCHROTRON  DIAMOND BEAMLINE I04-1    X-RAY DIFFRACTION
# 5R83             SYNCHROTRON  DIAMOND BEAMLINE I04-1    X-RAY DIFFRACTION
# 5R7Y             SYNCHROTRON  DIAMOND BEAMLINE I04-1    X-RAY DIFFRACTION
#
#            Experimental Method     Matthews Coefficient  \
# Entry ID  Matthews Coefficient  Percent Solvent Content
# 3OJC                      2.21                     44.3
# 5R84                      1.93                    36.19
# 5R83                      1.89                    35.05
# 5R7Y                      1.89                    35.03
#
#                 Percent Solvent Content Crystallization Method  ...  R Free  \
# Entry ID         Crystallization Method                     pH  ...  R Work
# 3OJC      VAPOR DIFFUSION, HANGING DROP                      7  ...  0.1699
# 5R84      VAPOR DIFFUSION, SITTING DROP                    NaN  ...  0.2167
# 5R83      VAPOR DIFFUSION, SITTING DROP                    NaN  ...  0.1758
# 5R7Y      VAPOR DIFFUSION, SITTING DROP                    NaN  ...  0.1794
#
#          R Work       R All             R Observed  \
# Entry ID  R All  R Observed  High Resolution Limit
# 3OJC      0.172      0.1715                   1.75
# 5R84        NaN      0.2205                   1.83
# 5R83        NaN      0.1778                   1.58
# 5R7Y        NaN      0.1822                   1.65
#
#                High Resolution Limit      Reflections For Refinement  \
# Entry ID  Reflections For Refinement  Structure Determination Method
# 3OJC                           91929                             SAD
# 5R84                           21632               FOURIER SYNTHESIS
# 5R83                           32895               FOURIER SYNTHESIS
# 5R7Y                           28722               FOURIER SYNTHESIS
#
#          Structure Determination Method  \
# Entry ID                    Space Group
# 3OJC                         P 21 21 21
# 5R84                            C 1 2 1
# 5R83                            C 1 2 1
# 5R7Y                            C 1 2 1
#
#                                               Space Group  \
# Entry ID                                  Source Organism
# 3OJC                                 Yersinia pestis CO92
# 5R84      Severe acute respiratory syndrome coronavirus 2
# 5R83      Severe acute respiratory syndrome coronavirus 2
# 5R7Y      Severe acute respiratory syndrome coronavirus 2
#
#                     Source Organism Molecular Weight (Entity)
# Entry ID  Molecular Weight (Entity)                       NaN
# 3OJC                         25.618                       NaN
# 5R84                         33.826                       NaN
# 5R83                         33.826                       NaN
# 5R7Y                         33.826                       NaN
#
# [5 rows x 28 columns]

# %%
main_df = main_df.drop(main_df.index[0])

# %%
main_df = main_df.shift(periods=1, axis="columns")
main_df['Entry ID'] = main_df.index

# %%
main_df["Collection Temperature"] = main_df["Collection Temperature"].astype("float64")
main_df["Matthews Coefficient"] = main_df["Matthews Coefficient"].astype("float64")
main_df["Percent Solvent Content"] = main_df["Percent Solvent Content"].astype("float64")
main_df["pH"] = main_df["pH"].astype("float64")
main_df["Temp (K)"] = main_df["Temp (K)"].astype("float64")
main_df["Average B Factor"] = main_df["Average B Factor"].astype("float64")
main_df["R Free"] = main_df["R Free"].astype("float64")
main_df["R Work"] = main_df["R Work"].astype("float64")
main_df["R All"] = main_df["R All"].astype("float64")
main_df["R Observed"] = main_df["R Observed"].astype("float64")
main_df["High Resolution Limit"] = main_df["High Resolution Limit"].astype("float64")
main_df["Reflections For Refinement"] = main_df["Reflections For Refinement"].astype("float64")
main_df.shape
main_df.to_pickle(pkl_path+"_clean.pkl")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-121d0f152191> in <module>
# ----> 1 main_df["Collection Temperature"] = main_df["Collection Temperature"].astype("float64")
#       2 main_df["Matthews Coefficient"] = main_df["Matthews Coefficient"].astype("float64")
#       3 main_df["Percent Solvent Content"] = main_df["Percent Solvent Content"].astype("float64")
#       4 main_df["pH"] = main_df["pH"].astype("float64")
#       5 main_df["Temp (K)"] = main_df["Temp (K)"].astype("float64")
#
# ~/miniforge3/envs/ARM_env/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5872         else:
#    5873             # else, only a single dtype is given
# -> 5874             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5875             return self._constructor(new_data).__finalize__(self, method="astype")
#    5876
#
# ~/miniforge3/envs/ARM_env/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~/miniforge3/envs/ARM_env/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~/miniforge3/envs/ARM_env/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/miniforge3/envs/ARM_env/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1095     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#    1096         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1097         return arr.astype(dtype, copy=True)
#    1098
#    1099     return arr.view(dtype)
#
# ValueError: could not convert string to float: 'Collection Temperature'

# %%
main_df.head()
# Out:
#   Entry ID  Collection Temperature Experimental Method  Matthews Coefficient  \
# 1     1HNA                     NaN   X-RAY DIFFRACTION                  2.33
# 2     1HOO                   298.0   X-RAY DIFFRACTION                  2.12
# 3     1HP0                   100.0   X-RAY DIFFRACTION                  2.02
# 4     1I0O                   100.0   X-RAY DIFFRACTION                  1.90
# 5     1I10                   100.0   X-RAY DIFFRACTION                  2.34
#
#    Percent Solvent Content         Crystallization Method   pH  \
# 1                    47.30                            NaN  NaN
# 2                    42.03                            NaN  6.5
# 3                    38.96  VAPOR DIFFUSION, HANGING DROP  8.5
# 4                    35.13  VAPOR DIFFUSION, HANGING DROP  6.0
# 5                    47.42  VAPOR DIFFUSION, HANGING DROP  7.5
#
#                             Crystal Growth Procedure  Temp (K)  \
# 1                                                NaN       NaN
# 2  SOAK OF THE NATIVE P 21 21 21 CRYSTAL WITH GPP...       NaN
# 3  100 mM tris, 1.6 M ammonium sulfate, pH 8.5, V...     293.0
# 4  K salt, pH 6.0, VAPOR DIFFUSION, HANGING DROP ...     298.0
# 5  protein solution: 28 mg/ml protein, 100 mM Na-...     291.0
#
#   Deposition Date PDB ID  Resolution (Å)  Average B Factor   R Free   R Work  \
# 1      1993-10-15   1HNA             1.85               NaN      NaN  0.22600
# 2      1996-04-26   1HOO             2.30            28.200  0.21000  0.18500
# 3      2000-12-12   1HP0             2.10               NaN  0.25400  0.19100
# 4      2001-01-29   1I0O             2.00               NaN  0.24600  0.20200
# 5      2001-01-30   1I10             2.30            27.066  0.25713  0.19722
#
#    R All  R Observed  High Resolution Limit  Reflections For Refinement  \
# 1    NaN     0.22600                   1.85                         NaN
# 2    NaN     0.18500                   2.30                     29591.0
# 3  0.191     0.19100                   2.10                     32960.0
# 4    NaN         NaN                   2.00                      3476.0
# 5    NaN     0.20024                   2.30                    105591.0
#
#   Structure Determination Method
# 1                            NaN
# 2                            NaN
# 3              FOURIER SYNTHESIS
# 4          MOLECULAR REPLACEMENT
# 5          MOLECULAR REPLACEMENT
